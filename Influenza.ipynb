# %% [markdown]
# # Creating a graph database for the Legislative Branch.

# %%
import yaml

with open("/Users/sahuguet/Documents/Dev/Influenza/legislators-current.yaml", 'r') as stream:
    try:
        data = yaml.load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# %% [markdown]
# CREATE (:`Government Organization` { name:"US Senate"})
# CREATE (:`Government Organization` { name:"House of Representatives"})

# %%
for people in data:
    name = people['name']['official_full'].replace('"','\\"')
    role = people['terms'][-1]['type']
    party = people['terms'][-1]['party']
    if role == 'sen':
        print """CREATE (:Person:Senator { name: "%s", party: "%s" })""" % (name, party)
    elif role == 'rep':
        print """CREATE (:Person:Representative { name: "%s", party: "%s" })""" % (name, party)
# Out:
# CREATE (:Person:Senator { name: "Sherrod Brown", party: "Democrat" })
# CREATE (:Person:Senator { name: "Maria Cantwell", party: "Democrat" })
# CREATE (:Person:Senator { name: "Benjamin L. Cardin", party: "Democrat" })
# CREATE (:Person:Senator { name: "Thomas R. Carper", party: "Democrat" })
# CREATE (:Person:Senator { name: "Robert P. Casey, Jr.", party: "Democrat" })
# CREATE (:Person:Senator { name: "Bob Corker", party: "Republican" })
# CREATE (:Person:Senator { name: "Dianne Feinstein", party: "Democrat" })
# CREATE (:Person:Senator { name: "Orrin G. Hatch", party: "Republican" })
# CREATE (:Person:Senator { name: "Amy Klobuchar", party: "Democrat" })
# CREATE (:Person:Senator { name: "Claire McCaskill", party: "Democrat" })
# CREATE (:Person:Senator { name: "Robert Menendez", party: "Democrat" })
# CREATE (:Person:Senator { name: "Bill Nelson", party: "Democrat" })
# CREATE (:Person:Senator { name: "Bernard Sanders", party: "Independent" })
# ...

# %% [markdown]
# -- Senators are MEMBER_OF the US Senate.
# MATCH (n:Senator)
# MATCH (senate:`Government Organization` { name: "US Senate"})
# CREATE (n)-[:MEMBER_OF]->(senate);
#
# -- Representatives are MEMBER_OF the House.
# MATCH (n:Representative)
# MATCH (house:`Government Organization` { name: "House of Representatives"})
# CREATE (n)-[:MEMBER_OF]->(house);
